# %% [markdown]
# # Colab Quickstart

# %%
## to delete /code if it already exists and you need to reclone the project
# !rm -r code

# %%
# !git clone --recursive https://github.com/SimoneColu/AML_error_recognition.git code
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 458, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 458 (delta 15), reused 26 (delta 8), pack-reused 420 (from 1)
# Receiving objects: 100% (458/458), 118.10 KiB | 16.87 MiB/s, done.
# Resolving deltas: 100% (297/297), done.
# Submodule 'annotations' (https://github.com/CaptainCook4D/annotations) registered for path 'annotations'
# Cloning into '/content/code/annotations'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 152 (delta 75), reused 108 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 793.14 KiB | 14.16 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Submodule path 'annotations': checked out '0e9a108be2cbcbcbd592e7418c0ab9c16232d27a'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TODO: update the paths below with your own

# !mkdir code/data
# !unzip "/content/drive/MyDrive/omnivore.zip" -d code/data/video

# !mkdir -p code/checkpoints/error_recognition_best/MLP/omnivore
# Sposta il file nella cartella di destinazione
# !cp "/content/drive/MyDrive/error_recognition_MLP_omnivore_step_epoch_43.pt" code/checkpoints/error_recognition_best/MLP/omnivore/
# Out:
# Archive:  /content/drive/MyDrive/omnivore.zip
#    creating: code/data/video/omnivore/
#   inflating: code/data/video/omnivore/22_37_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_38_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_17_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_16_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/13_14_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/10_7_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/22_2_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/21_47_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_42_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_39_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/2_8_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/29_28_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_23_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_26_360p.mp4_1s_1s.npz
# ...

# %%
# !pip install torcheval
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 16.9 MB/s eta 0:00:00
# ...

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_step_epoch_43.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.31, Precision=0.33 (Positives: 1211)
# Error Type 3.0: Recall=0.32, Precision=0.31 (Positives: 357)
# Error Type 4.0: Recall=0.32, Precision=0.34 (Positives: 1133)
# Error Type 5.0: Recall=0.31, Precision=0.34 (Positives: 1390)
# Error Type 6.0: Recall=0.32, Precision=0.33 (Positives: 848)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.18, Precision=0.62 (Positives: 33)
# Error Type 3.0: Recall=0.18, Precision=0.59 (Positives: 4)
# Error Type 4.0: Recall=0.17, Precision=0.60 (Positives: 26)
# Error Type 5.0: Recall=0.18, Precision=0.60 (Positives: 17)
# Error Type 6.0: Recall=0.18, Precision=0.61 (Positives: 27)
# ----------------------------------------------------------------
# ...

# %%
# %%bash
#
# cd code
# python train_er.py \
#     --variant LSTM \
#     --backbone omnivore \
#     --split step \
#     --modality video

# %%
# %%bash
# cd code
# python -m core.evaluate --variant LSTM --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/LSTM/omnivore/error_recognition_step_omnivore_LSTM_video_best.pt \
#   --split step --threshold 0.6
